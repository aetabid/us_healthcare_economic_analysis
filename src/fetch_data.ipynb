# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/healthcare_indicators.csv")
df
# Out:
#            date  medical_cpi  healthcare_employment  personal_consumption  \
# 0    1947-01-01       13.200                    NaN                   NaN
# 1    1947-02-01       13.300                    NaN                   NaN
# 2    1947-03-01       13.300                    NaN                   NaN
# 3    1947-04-01       13.400                    NaN                   NaN
# 4    1947-05-01       13.500                    NaN                   NaN
# ..          ...          ...                    ...                   ...
# 949  2026-02-01      592.554                    NaN               129.539
# 950  2026-03-01      591.587                    NaN               130.403
# 951  2026-04-01      591.202                    NaN               130.938
# 952  2026-05-01      593.057                    NaN               131.527
# 953  2026-06-01          NaN                    NaN                   NaN
#
#      disposable_income  unemployment  retail_sales
# ...

# %%
#df.info()
#df.head()
print(df.columns)
print(df.isnull().sum())
# Out:
# Index(['date', 'medical_cpi', 'healthcare_employment', 'personal_consumption',
#        'disposable_income', 'unemployment', 'retail_sales'],
#       dtype='object')
# date                       0
# medical_cpi                2
# healthcare_employment    932
# personal_consumption     145
# disposable_income        145
# unemployment              13
# retail_sales             541
# dtype: int64
